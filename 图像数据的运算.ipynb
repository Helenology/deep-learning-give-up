# %%
from PIL import Image
photo = Image.open('./head.jpg')
photo
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024 at 0x7FCE1952A410>

# %%
# 图像的大小
print(photo.size)
# Out:
# (1024, 1024)

# %%
# 修改图皮的大小
photo = photo.resize([128, 128])
print(photo.size)
photo
# Out:
# (128, 128)
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FCE19505D50>

# %%
# 转换图片为矩阵类型
type(photo)
import numpy as np
Im = np.array(photo)
print(Im.shape)
# Out:
# (128, 128, 3)

# %%
# 打印出Im第0各通道的矩阵
Im[:, :, 0]
# Out:
# array([[167, 173, 176, ..., 204, 215, 194],
#        [172, 168, 165, ..., 205, 193, 197],
#        [165, 168, 176, ..., 199, 197, 212],
#        ...,
#        [160, 164, 168, ..., 207, 188, 197],
#        [169, 160, 169, ..., 197, 208, 192],
#        [167, 165, 159, ..., 189, 207, 207]], dtype=uint8)

# %%
# 尺度变化，每个元素取值 / 255
Im = Im / 255
print(Im[:, :, 0])
# Out:
# [[0.65490196 0.67843137 0.69019608 ... 0.8        0.84313725 0.76078431]
#  [0.6745098  0.65882353 0.64705882 ... 0.80392157 0.75686275 0.77254902]
#  [0.64705882 0.65882353 0.69019608 ... 0.78039216 0.77254902 0.83137255]
#  ...
#  [0.62745098 0.64313725 0.65882353 ... 0.81176471 0.7372549  0.77254902]
#  [0.6627451  0.62745098 0.6627451  ... 0.77254902 0.81568627 0.75294118]
#  [0.65490196 0.64705882 0.62352941 ... 0.74117647 0.81176471 0.81176471]]

# %%
# 图像展示
import matplotlib.pyplot as plt
plt.imshow(Im)

# %%
# 图像数据的代数运算
Im1 = Im + 0.5
Im2 = 1 - Im
Im3 = 0.5 * Im
Im4 = Im / 0.5
plt.figure()
fig, ax = plt.subplots(1, 4)
fi
